# %% [markdown]
# # C5.01 Corpus agenti - Tema 2
#
#
# Scop: ne uităm la `data/corpus_typed.json`, verificăm distribuția bulelor și alegem ce exemple merită păstrate pentru vector store.

# %% [markdown]
# ## 1. Setup

# %%
from pathlib import Path
import os
import pandas as pd

PROJECT_ROOT = Path(r"C:\Users\ioana\Desktop\curs AI Engineering\echochamber-project-team-1")
os.chdir(PROJECT_ROOT)
DATA_PATH = Path("data/typed/corpus_typed.jsonl")

# %%
DATA_PATH
# Out:
# WindowsPath('data/typed/corpus_typed.jsonl')

# %% [markdown]
# ## 2. Încărcăm corpusul

# %%
df = pd.read_json(DATA_PATH, lines=True)
df.head(2)
# Out:
#                                           id  \
# 0  yt_Tx8GhU2LeyI_UgwoWOyzF2UbPYnguUB4AaABAg
# 1  yt_joXkZDqGZQU_Ugyqb1XZ7P8GTnJS_4p4AaABAg
#
#                                                 text     source_channel  \
# 0  Am toată încrederea că oameni ( de bine ) ca :...  AlephNewsOfficial
# 1  Semneaza Bo$$ ca la urmatoarele alegerii nu ma...       NicusorDanRO
#
#      channel_family                                        video_title  \
# 0        mainstream  ATENȚIE: România e „binevenită” să aplice iar ...
# 1  mainstream_actor  🟢 Declarații de presă comune cu Președintele U...
#
#   target_refined stance_to_target  confidence            discourse_type  \
# 0         simion             anti         0.9   T3_opozitie_suveranista
# 1    nicusor_dan             anti         0.9  T2_grievance_anti_sistem
#
#        discourse_subtype type_confidence
# 0        opozitie_difuza          medium
# 1  grievance_mobilizator          medium

# %% [markdown]
# ## 3. Vedem structura datelor

# %%
len(df)
# Out:
# 896

# %%
print("Coloane:")
df.columns
# Out:
# Coloane:
# Index(['id', 'text', 'source_channel', 'channel_family', 'video_title',
#        'target_refined', 'stance_to_target', 'confidence', 'discourse_type',
#        'discourse_subtype', 'type_confidence'],
#       dtype='str')

# %%
df["discourse_type"].value_counts(dropna=False)
# Out:
# discourse_type
# T3_opozitie_suveranista       150
# T1_suport_personalist         150
# T5_pro_democratic_european    150
# T2_grievance_anti_sistem      149
# T6_afectiv_pozitional         149
# T4_conspiratie_externalism    148
# Name: count, dtype: int64

# %%
## Exemplu de text pentru fiecare tip de discurs

# %%
for bubble in df["discourse_type"].value_counts().index:
    print("\n" + "="*80)
    print(bubble)
    print("="*80)
    
    sample = df[df["discourse_type"] == bubble]["text"].dropna().head(5)
    
    for i, text in enumerate(sample, 1):
        print(f"\n{i}. {text[:50]}")
# Out:
# ================================================================================
# T3_opozitie_suveranista
# ================================================================================
#
# 1. Am toată încrederea că oameni ( de bine ) ca : G S
#
# 2. Apropo de avalansa de troli ce se devarsa si acum
#
# 3. Aceasta nu este o emisiune....este o regizare mize
#
# 4. La pregatit bine Putin a investit bani in Guru Geo
#
# 5. Eu am vorbit cu susținători de ai lui CG, îs deran
#
# ================================================================================
# T1_suport_personalist
# ================================================================================
#
# 1. Ne au distrus hoții 😢,,,nu ne mai aparține nimic,,
#
# 2. Era si timpul sa treceti la atac, prea multa defen
#
# 3. Vă mulțumim și noi și copii noștri care lucrează î
#
# 4. 1:35 NOI știm că Sistemul ÎL hărțuiește mișelește
#
# 5. Ideea că poporul are dreptul sau chiar datoria de
#
# ================================================================================
# T5_pro_democratic_european
# ================================================================================
#
# 1. Nu are Ce cauta pe teritoriulRomaniei, indiferent
#
# 2. Tipul care și-a dat demisia în noiembrie la cum gâ
#
# 3. + la asta, d. Președinte, trebuie sa existe O MAJO
#
# 4. Mă bucur să văd un Președinte care se comportă fir
#
# 5. Deci exemplu asta cu Parisul cred ca e cea mai tar
#
# ================================================================================
# T2_grievance_anti_sistem
# ================================================================================
#
# 1. Semneaza Bo$$ ca la urmatoarele alegerii nu mai ie
#
# 2. ESTE NEVOIE DE O FESTAÑIE LA TOATE NIVELURILE STAT
#
# 3. Orcii fac ore suplimentare!! Bravo! Daca ati munci
#
# 4. Câtă nesimțire!!! Câtă hoție pe fațaă!!! Ce răspun
#
# 5. Biserica, aceasta sinecura de sifonat bani, este c
#
# ================================================================================
# T6_afectiv_pozitional
# ================================================================================
#
# 1. D.nul Presedinte m-ati fācut să plâng, am simtit e
#
# 2. Extraordinara conversatie ! Felicitari d-le Isaila
#
# 3. SĂRBĂTORI FERICITE DOMNULUI PREȘEDINTE ÎMPREUNĂ CU
#
# 4. Poate repeta vizita președintele NDan la mai multe
#
# 5. Asta inseamna Romania educata , nu cea a lui Johao
#
# ================================================================================
# T4_conspiratie_externalism
# ================================================================================
#
# 1. Dar de românii din Ucraina care și-au pierdut drep
#
# 2. Ținând cont de microfoane, unde sunt microfoanele
#
# 3. Aveti incredere in cine.a juns sa fie in CSAT ?. N
#
# 4. "Pe gratis" .. sau nu. La simulare copiii mei nu a
#
# 5. Ce aveti bă cu bietul om? Tot nu intelegeti ca Mac

# %% [markdown]
# # 4. Pastram doar 150 de bula

# %%
# Alegem un subset simplu pentru curs: maximum 150 texte per bulă

N_PER_BUBBLE = 150

df_sample = (
    df[df["discourse_type"].notna()]
    .sort_values("type_confidence", ascending=False)
    .groupby("discourse_type", group_keys=False)
    .head(N_PER_BUBBLE)
    .copy()
)

df_sample["discourse_type"].value_counts()
# Out:
# discourse_type
# T3_opozitie_suveranista       150
# T1_suport_personalist         150
# T5_pro_democratic_european    150
# T2_grievance_anti_sistem      149
# T6_afectiv_pozitional         149
# T4_conspiratie_externalism    148
# Name: count, dtype: int64

# %%
# Păstrăm doar coloanele utile și salvăm corpusul pentru etapa următoare

keep_cols = [
    "id", "text", "source_channel", "channel_family", "video_title",
    "target_refined", "stance_to_target",
    "confidence", "discourse_type", "discourse_subtype", "type_confidence"
]

df_sample = df_sample[keep_cols].drop_duplicates(subset="text").copy()

OUT_PATH = Path("data/typed/corpus_c5_sample.jsonl")
df_sample.to_json(OUT_PATH, orient="records", lines=True, force_ascii=False)

print(df_sample.shape)
print(OUT_PATH)
df_sample.head(2)
# Out:
# (896, 11)
# data\typed\corpus_c5_sample.jsonl
#                                             id  \
# 0    yt_Tx8GhU2LeyI_UgwoWOyzF2UbPYnguUB4AaABAg
# 402  yt_opXUERp44N4_UgyRMEikJl6sUpuMCMp4AaABAg
#
#                                                   text  \
# 0    Am toată încrederea că oameni ( de bine ) ca :...
# 402  De coiful dacic, de colectiv, de dosarul revol...
#
#                     source_channel channel_family  \
# 0                AlephNewsOfficial     mainstream
# 402  CălinGeorgescu-CanalulOficial  sovereigntist
#
#                                            video_title target_refined  \
# 0    ATENȚIE: România e „binevenită” să aplice iar ...         simion
# 402  Călin Georgescu - Despăducherea și Revoluția I...      georgescu
#
#     stance_to_target  confidence              discourse_type  \
# 0               anti         0.9     T3_opozitie_suveranista
# 402          unclear         0.9  T4_conspiratie_externalism
#
#            discourse_subtype type_confidence
# 0            opozitie_difuza          medium
# 402  conspiratie_suveranista          medium

# %% [markdown]
# ## 5. Exportul bulelor finale
# În această etapă transformăm corpusul tipologizat în fișiere separate, câte unul pentru fiecare bulă finală.
# Codurile `T1`, `T2`, `T3`, `T4`, `T5` vin din adnotare, dar în aplicație folosim numele finale ale agenților:
# | Agent | Personalitate | Cum vorbește | Ce îl definește |
# |---|---|---|---|
# | Personalist-salvator | devotat, admirativ, sigur | laudativ, emoțional, încrezător | vede liderul ca soluție excepțională |
# | Anti-sistem | furios, suspicios, dezamăgit | acuzator, moralizator, direct | vede instituțiile și „sistemul” ca profund compromise |
# | Anti-suveranist | critic, vigilent, defensiv | contestatar, mai argumentativ | respinge liderii și discursul suveranist |
# | Conspiraționist | alarmist, hiper-suspicios | speculativ, revelator, totalizant | explică evenimentele prin forțe ascunse și actori externi |
# | Pro-european | normativ, moderat, legalist | sobru, justificativ, procedural | apără regulile, instituțiile și ancorarea europeană |
# `T6_afectiv_pozitional` nu devine agent principal în C5. Rămâne categorie transversală / rezervă.

# %%
BUBBLES = {
    "T1_suport_personalist": {
        "agent": "Personalist-salvator",
        "slug": "personalist_salvator",
        "personality": "devotat, admirativ, sigur",
        "speaks": "laudativ, emoțional, încrezător",
        "definition": "vede liderul ca soluție excepțională",
    },
    "T2_grievance_anti_sistem": {
        "agent": "Anti-sistem",
        "slug": "anti_sistem",
        "personality": "furios, suspicios, dezamăgit",
        "speaks": "acuzator, moralizator, direct",
        "definition": "vede instituțiile și „sistemul” ca profund compromise",
    },
    "T3_opozitie_suveranista": {
        "agent": "Anti-suveranist",
        "slug": "anti_suveranist",
        "personality": "critic, vigilent, defensiv",
        "speaks": "contestatar, mai argumentativ",
        "definition": "respinge liderii și discursul suveranist",
    },
    "T4_conspiratie_externalism": {
        "agent": "Conspiraționist",
        "slug": "conspirationist",
        "personality": "alarmist, hiper-suspicios",
        "speaks": "speculativ, revelator, totalizant",
        "definition": "explică evenimentele prin forțe ascunse și actori externi",
    },
    "T5_pro_democratic_european": {
        "agent": "Pro-european",
        "slug": "pro_european",
        "personality": "normativ, moderat, legalist",
        "speaks": "sobru, justificativ, procedural",
        "definition": "apără regulile, instituțiile și ancorarea europeană",
    },
}

# %%
"""
OUT_DIR = Path("data/bubbles")
OUT_DIR.mkdir(parents=True, exist_ok=True)

N_PER_BUBBLE = 50

for old_type, meta in BUBBLES.items():
    bubble_df = (
        df_sample[df_sample["discourse_type"] == old_type]
        .drop_duplicates(subset="text")
        .head(N_PER_BUBBLE)
        .copy()
    )

    bubble_df["agent"] = meta["agent"]
    bubble_df["slug"] = meta["slug"]
    bubble_df["personality"] = meta["personality"]
    bubble_df["speaks"] = meta["speaks"]
    bubble_df["definition"] = meta["definition"]
    bubble_df["source_type"] = old_type

    out_path = OUT_DIR / f"{meta['slug']}.jsonl"
    bubble_df.to_json(out_path, orient="records", lines=True, force_ascii=False)

    print(f"{meta['agent']}: {len(bubble_df)} texte -> {out_path}")

"""
# Out:
# '\nOUT_DIR = Path("data/bubbles")\nOUT_DIR.mkdir(parents=True, exist_ok=True)\n\nN_PER_BUBBLE = 50\n\nfor old_type, meta in BUBBLES.items():\n    bubble_df = (\n        df_sample[df_sample["discourse_type"] == old_type]\n        .drop_duplicates(subset="text")\n        .head(N_PER_BUBBLE)\n        .copy()\n    )\n\n    bubble_df["agent"] = meta["agent"]\n    bubble_df["slug"] = meta["slug"]\n    bubble_df["personality"] = meta["personality"]\n    bubble_df["speaks"] = meta["speaks"]\n    bubble_df["definition"] = meta["definition"]\n    bubble_df["source_type"] = old_type\n\n    out_path = OUT_DIR / f"{meta[\'slug\']}.jsonl"\n    bubble_df.to_json(out_path, orient="records", lines=True, force_ascii=False)\n\n    print(f"{meta[\'agent\']}: {len(bubble_df)} texte -> {out_path}")\n\n'

# %% [markdown]
# ## 6. Alege agentul tău și verifică textele
# Fiecare membru al echipei lucrează pe un singur agent.
# Datele vin din `df_sample`, iar agentul este legat de eticheta tehnică `discourse_type`.
# Scopul este să alegi aproximativ 50 texte bune pentru agentul tău.

# %%
# Alegeți un agent și încărcați textele corespunzătoare pentru etapa următoare
AGENTS = {
    "Personalist-salvator": {
        "type": "T1_suport_personalist",
        "slug": "personalist_salvator",
        "personality": "devotat, admirativ, sigur",
        "speaks": "laudativ, emoțional, încrezător",
        "definition": "vede liderul ca soluție excepțională",
    },
    "Anti-sistem": {
        "type": "T2_grievance_anti_sistem",
        "slug": "anti_sistem",
        "personality": "furios, suspicios, dezamăgit",
        "speaks": "acuzator, moralizator, direct",
        "definition": "vede instituțiile și „sistemul” ca profund compromise",
    },
    "Anti-suveranist": {
        "type": "T3_opozitie_suveranista",
        "slug": "anti_suveranist",
        "personality": "critic, vigilent, defensiv",
        "speaks": "contestatar, mai argumentativ",
        "definition": "respinge liderii și discursul suveranist",
    },
    "Conspiraționist": {
        "type": "T4_conspiratie_externalism",
        "slug": "conspirationist",
        "personality": "alarmist, hiper-suspicios",
        "speaks": "speculativ, revelator, totalizant",
        "definition": "explică evenimentele prin forțe ascunse și actori externi",
    },
    "Pro-european": {
        "type": "T5_pro_democratic_european",
        "slug": "pro_european",
        "personality": "normativ, moderat, legalist",
        "speaks": "sobru, justificativ, procedural",
        "definition": "apără regulile, instituțiile și ancorarea europeană",
    },
}

MY_AGENT = "Pro-european"  # Alegeți unul dintre agenți: "Personalist-salvator", "Anti-sistem", "Anti-suveranist", "Conspiraționist", "Pro-european"

meta = AGENTS[MY_AGENT]

my_df = (
    df_sample[df_sample["discourse_type"] == meta["type"]]
    .drop_duplicates(subset="text")
    .copy()
)

print("Agent:", MY_AGENT)
print("Tip discurs:", meta["type"])
print("Texte disponibile:", len(my_df))

my_df[["id", "type_confidence", "discourse_subtype", "text"]].head(2)
# Out:
# Agent: Pro-european
# Tip discurs: T5_pro_democratic_european
# Texte disponibile: 150
#                                             id type_confidence  \
# 420  yt_FAe_Sqr2vfU_UgzfkQjlhFS0o3ZaCMl4AaABAg          medium
# 547  yt_XlCX1l_6feU_UgwBIpp5ZbEtJkybe3t4AaABAg          medium
#
#            discourse_subtype  \
# 420  legitimitate_pluralista
# 547  legitimitate_pluralista
#
#                                                   text
# 420  Mă bucur să văd un Președinte care se comportă...
# 547  meritocratie in politica inseamna, totusi, alt...

# %% [markdown]
# ### Cum verifici textele
# Citește textele afișate mai jos.
# Dacă un text este slab, copiază ID-ul lui în lista `REMOVE_IDS`.
# Elimină texte prea scurte, duplicate, ambigue sau care nu exprimă clar vocea agentului.|
#
# - pot sa folosesc un notepad pentru IDs
# daca nu gasesti 50 de comentarii bune, incarca mai multe.
# - poti folosi si alte metode (export text, csv) pentru vizualizarea si alegerea comentariilor

# %%
for _, row in my_df.head(70).iterrows():
    print("=" * 80)
    print("ID:", row["id"])
    print("Confidence:", row["type_confidence"])
    print("Subtype:", row["discourse_subtype"])
    print(row["text"][:700])
# Out:
# ================================================================================
# ID: yt_FAe_Sqr2vfU_UgzfkQjlhFS0o3ZaCMl4AaABAg
# Confidence: medium
# Subtype: legitimitate_pluralista
# Mă bucur să văd un Președinte care se comportă firesc și zâmbește atât de frumos. Îmi dă speranța că lucrurile merg pe făgașul normalității. 👏🏻
# ================================================================================
# ID: yt_XlCX1l_6feU_UgwBIpp5ZbEtJkybe3t4AaABAg
# Confidence: medium
# Subtype: legitimitate_pluralista
# meritocratie in politica inseamna, totusi, altceva. poti sa fii toba, dar in functie sa fii praf. apoi, e imperios necesar sa fiti ideologizati, sa stimulati opinii divergente, dar in interiorul acelei ideologii. sa existe obligatoriu democratie de partid, numai asa puteti creste ca partid. dar mai intai sa cristalizati ideologia politica. atentie! ideologie nu inseamna numai drepturi, stanga presupune socialism, trebuie sa invatati socialism, multi va votam pentru ca suntem socialisti. inca ceva, daca nu ai vointa de putere nu te bagi in politica.
# ================================================================================
# ID: yt_Fcmw2yFzz8I_UgxuNvJZTDz3pFm5Ijh4AaABAg
# Confidence: medium
# Subtype: legitimitate_pluralista
# Deci exemplu asta cu Parisul cred ca e cea mai tare gluma din lume. Daca te uiti pe forumuri foarte multi oameni se plang de masurile socialiste implementate in Paris. Pana la urma ideea asta ca x lucru este mai BUN este pur si simplu o poveste.... o poveste proasta in ideea in care ne impartim in SOFERI si CETATENI. Este pur si simplu stupid. Important este pana la urma ce doreste majoritatea. Daca in Paris majoritatea doreste sa scoata masinile de pe strada poate aflam ca in Bucuresti majoritatea nu doreste asta. Hai totusi sa lasam un pic BINELE asta si sa vedem totusi ce fel de oras isi doresc cei care locuiesc in acel oras. Ca degeaba te plangi ca e trafic daca primul om care iti promit
# ================================================================================
# ID: yt_Gk7qe_F1KWE_Ugw6Diry83RDiew6P4V4AaABAg
# Confidence: medium
# Subtype: legitimitate_pluralista
# Ce sunt cu torți trolli ăștia din comentarii? As vrea să mă iau de iei dar mi-aș irosi timpul. Ma bucur ca am pus ștampila pe SENS indiferent de punctaj, fie 1% sau 99%. Prefer sa votez un partid care ma reprezintă decât să votez pe altcineva care nu ma reprezintă, ar fi și mai rău ca acel partid care nu ma reprezintă și mi-a luat votul sa intre in parlament. Practic mi-am făcut rău singur
# ================================================================================
# ID: yt_Pk7Qkhnt4Bs_UgwxY19uJCh0c9RP4U54AaABAg
# Confidence: medium
# Subtype: legitimitate_pluralista
# Sanatate si putere de munca domnule presedinte. Voi lasa un comentariu chiar daca nu va ajunge unde trebuie. E musai ca un presedinte sa aiba consilieri " specialisti". Nimeni nu stie si nu se pricepe la tot. Doar asa puteti aborda toate problemele si domeniile. Acest comentariu nu e pentru dumneavoastra ci pentru cei care va contesta . Ca se intampla un incident ca la Timisoara e firesc si mai mult in ochii familiei mele va face mai " uman" , mai apropiat de noi. O problema e ca multi romani carcotasi nu inteleg sau nu vor sa inteleaga ca puterile dumneavoastra ca Presedinte sant limitate de Constitutia Romaniei si ca " Parlamentul face si drege" De aceea parerea mea a ca acest " fapt" treb
# ================================================================================
# ID: yt_6_Hc2S02Duw_UgwTw7_YpNZEUGkYDb94AaABAg
# Confidence: medium
# Subtype: legitimitate_pluralista
# Nu are Ce cauta pe teritoriulRomaniei, indiferent ca are s-au nu are , ca sint s-au ca nu sint defensive, s-au offensive- nu au acordul poporului
# ================================================================================
# ID: yt_yEuctxNb4O0_UgxTCkwcP96Sb5_Rpht4AaABAg
# Confidence: medium
# Subtype: legitimitate_pluralista
# Tipul care și-a dat demisia în noiembrie la cum gândește și vorbește merita sa fie ministrul justiției. Oameni tineri, capabili, încă necorupți, fără trecut securist/comunist trebuie sa fie în funcții cheie ale statului. Vezi miniștrii USR, maxim 40 de ani, pregătiți, implicați....
# ================================================================================
# ID: yt_kLdQS9N5cBU_UgxIxee_zETaR-Dlu894AaABAg
# Confidence: medium
# Subtype: legitimitate_pluralista
# + la asta, d. Președinte, trebuie sa existe O MAJORITATE a cetatenilor si in Romănia..., care sa doreasca UNIREA....
# ================================================================================
# ID: yt_2Lv_gN_AWwQ_UgzFFGBpklf96HP19bV4AaABAg
# Confidence: high
# Subtype: aparare_institutionala_procedurala
# Platitorul care nu vrea sa plateasca , din diverse motive , este executat silit de catre un executor in baza unei hotarari definitive . Este simplu si legal .
# ================================================================================
# ID: yt_b8hlh8LCd8E_UgzOPkgpiloljPi-yTt4AaABAg
# Confidence: high
# Subtype: aparare_institutionala_procedurala
# Aici in Italia este o firma care se ocupa cu parcarea, amenzile se platesc la politie, politia este necesara, nu pt parcare, pt linistea si ocrotirea odinii publice si legile trebuie executate.
# ================================================================================
# ID: yt_hJvnXa_skCo_Ugwl9VUvwIbp8n77RRZ4AaABAg
# Confidence: high
# Subtype: pro_european_ancorare
# Adevăruri Secrete ! E un nume mare pentru un conținut mic. Critici Europa și SUA în timp ce folosești o platformă americană și trăiești în Europa — contradicția asta spune tot. Nu aduci dovezi, doar repeți aceleași narative ca un ecou. Asta nu e analiză, e propagandă. Iar realitatea, indiferent cât o ignori, rămâne aceeași: armata SUA este în continuare cea mai avansată și capabilă din lume. Diferența nu e de opinii, e de tehnologie și putere reală.
# ================================================================================
# ID: yt_5AGO7BTxl_U_UgwR6wwc8lV1Euuds1F4AaABAg
# Confidence: high
# Subtype: aparare_institutionala_procedurala
# Nicușor a fost votat, Nicușor președinte. Felicitari puțin spus
# ================================================================================
# ID: yt_5AGO7BTxl_U_Ugym2-E1D2V_EKnXirZ4AaABAg
# Confidence: high
# Subtype: pro_european_ancorare
# Trăiască președintele nostru..Nicușor Dan..trăiască democrația..trăiască Europa...❤
# ================================================================================
# ID: yt_5AGO7BTxl_U_UgxstZ8toZX0SygswD54AaABAg
# Confidence: high
# Subtype: aparare_institutionala_procedurala
# Nu mai mințiți poporul..va obosiți degeaba .Nicușor e președinte...
# ================================================================================
# ID: yt_6X2UJgJgGTA_UgxYhIaYKMi7599Nrpx4AaABAg
# Confidence: high
# Subtype: pro_european_ancorare
# 30% din It-isti din America sunt români! A doua limbă, după cea engleză,din această comunite este limba română!
# ================================================================================
# ID: yt_Jc0ii3v3agI_UgxA96HaCQQzZ-HDRph4AaABAg
# Confidence: high
# Subtype: aparare_institutionala_procedurala
# Mulțumim @danielroxin! Indubitabil ar trebui să fiiți Ministrul Culturii! Să nu fie expus în alte țări. Să nu fie păstrat într-o ladă în subsolul vreunui muzeu.
# ================================================================================
# ID: yt_Dvw1tNAc_kU_UgyITjsbEM1k4_t9vqZ4AaABAg
# Confidence: high
# Subtype: pro_european_ancorare
# Cu Rusia nu se poate negocia, cât timp e condusă de un regim totalitar, pentru că un regim terorist nu respectă nimic. Orice încetare a focului fără retragerea trupelor ruse din granițele recunoscute internațional ale Ucrainei e o încurajare pentru toți agresorii din lume. Încetarea focului se poate face doar după retragerea trrupelor ruse din Ucraina și oferirea de garanții din partea NATO pentru Ucraina, în caz de reluare a agresiunii ruse.
# ================================================================================
# ID: yt_b8hlh8LCd8E_UgwKkGTrRYgdXJzq0ud4AaABAg
# Confidence: high
# Subtype: pro_european_ancorare
# Trăiască Armata Română, Poliția Română, Jandarmeria Română și chiar și Poliția Locală care le stă unora în gât! Atâta timp cât aceste instituții funcționează încă mă simt în siguranță în această țară. Cine este nemulțumit are posibilitatea să meargă și în alte țări, că de aia suntem în Uniunea Europeană, să vadă cum este și pe acolo iar dacă consideră că sunt mai în siguranță să rămână și să trăiască acolo că nu este ținut nimeni aici cu forța. Iar cei care tot cer desființarea unora sau altora și probabil se cred niște sfinți au curaj să jure cu mâna pe biblie că nu au traversat în viața lor prin locuri nepermise, că nu au parcat niciodată neregulamentar sau că și -au îndeplinit întotdeauna
# ================================================================================
# ID: yt_pfOUEvkf38M_Ugxd5bLTeUQJNpCMxBF4AaABAg
# Confidence: high
# Subtype: pro_european_ancorare
# 👍🏻💯 De ce FUgem de dezbateri ❓🪑🪑🪑 Nicușor președinte 🇷🇴🇲🇩🇪🇺💪🏻💯
# ================================================================================
# ID: yt_z5vgJ83XHjI_UgwnuH-XLzCHQFfL-8t4AaABAg
# Confidence: high
# Subtype: aparare_institutionala_procedurala
# Felicitari dvoastra si invitatei de exceptie!💯O sustinem pe dna ministru
# ================================================================================
# ID: yt_z5vgJ83XHjI_UgxuczMuq8YhgHT0vZ54AaABAg
# Confidence: high
# Subtype: pro_european_ancorare
# Doamnă ministru...🎩 Mult succes! Proiect de țară: USR. 50%+ în viitorul parlament!!! 🇪🇺🇺🇦🇲🇩🇷🇴
# ================================================================================
# ID: yt_zppyrH7QjDY_UgyEf8fuROPwbLU34nN4AaABAg
# Confidence: high
# Subtype: pro_european_ancorare
# Echilibristică între centre de putere? Iar vb prostii, UE este clar singura opțiune pt noi acum, cu această tumoră maga la putere în SUA.
# ================================================================================
# ID: yt_z5vgJ83XHjI_UgzjpuW8kv4vQ0f4nsR4AaABAg
# Confidence: high
# Subtype: aparare_institutionala_procedurala
# Doamnei ministru îi doresc multă forță să ducă la capăt proiectele începute,și multe altele. Dreaptă la propriu și la figurat,tot așa mereu.
# ================================================================================
# ID: yt_FzOggnmtMJI_UgzXRHv9anSjiNZzbzd4AaABAg
# Confidence: high
# Subtype: pro_european_ancorare
# respect republica Moldova, pentru puterea cu care lupta pentru apararea democratiei!
# ================================================================================
# ID: yt_hKbL21Wy4Bk_UgwMbGWXWag5eN879ER4AaABAg
# Confidence: high
# Subtype: pro_european_ancorare
# Fals, armele sunt plătite de UE și livrate Ucrainei, rățoiul nu dă nimic !
# ================================================================================
# ID: yt_2Lv_gN_AWwQ_UgzQzNX1xQTBSnEqo6F4AaABAg
# Confidence: high
# Subtype: aparare_institutionala_procedurala
# Mi a plăcut cum a pus problema Domna respectivă de 70 ani care a vorbit la început 👍👍👍 Dreptul democratic - toți au drepturi iar dacă au dreptate să și apere cauza fără multe manevre politice
# ================================================================================
# ID: yt_lhS48YD1mI4_UgwA164EyKTYyZZ3X_J4AaABAg
# Confidence: high
# Subtype: aparare_institutionala_procedurala
# Cine face un efort sa ii faca o sesizare la Anaf la nasturel ăsta?
# ================================================================================
# ID: yt_cok3YTTn8sg_Ugw9joa6s_uddLOSdCZ4AaABAg
# Confidence: high
# Subtype: aparare_institutionala_procedurala
# Catu sa plateasca, daca nu se pruc probe ale unei decizii la nivel UE. Si nici decixcizia apriorica de reducere a comenzii bazate pe estimarea corecta a numarului imbecililor antivaccinisti romani nu era posibila. Voiculescu nu, ca s-a opus faptic si oficial deciziei de procurare.
# ================================================================================
# ID: yt_SyZbp3TS0cw_UgzpxKY8tcGdsip3CDJ4AaABAg
# Confidence: high
# Subtype: aparare_institutionala_procedurala
# România dlor generali ai României să stăm drepți este un imbold al trupului uman românesc istoric dar mulți au murit, și este timpul să gândim drept constituțional și instituții publice ale României 🇷🇴
# ================================================================================
# ID: yt_s8rlvtZXuCs_UgwdQoYkpl088nszo8J4AaABAg
# Confidence: high
# Subtype: pro_european_ancorare
# „Aderarea la UE nu înseamnă și aderarea la NATO”, dar este o condiție sine qua non.
# ================================================================================
# ID: yt_yEuctxNb4O0_UgxBCZlT5ONt83PJ4xp4AaABAg
# Confidence: high
# Subtype: aparare_institutionala_procedurala
# Sa fie corecti magistratii😢😢😢 Doresc sa pun o intrebare daca ai o Reclamatie de a fii JUDECAT UNDE. TREBUIE SA TE ADRESEZ PRIMADATA. 😢😢😢😢😢
# ================================================================================
# ID: yt_u0rKP8iTIco_UgxfnSx_yST1uW3pfyh4AaABAg
# Confidence: high
# Subtype: aparare_institutionala_procedurala
# La faza cu lumanari "de acasa"........bro nu mi-o lua in nume de rau, nici eu nu suntr de acord cu mizeria asta dar vorba aia "unde e lege, nu e tocmeala" adica, este ilegal sa mergi gen la biserica cu lumanari "de acasa" , uite aici de ce : """"Biserica Ortodoxă Română deține un drept exclusiv de producție și vânzare a lumânărilor, stabilit printr-o lege din 1992 (Legea 103/1992)""" REPET......este o MIZERIE grosolana asa ceva......dar totusi este LEGE. Deci csf.....ncsf
# ================================================================================
# ID: yt_nZXd79SHQ-0_UgyHxP_2f1OIN8shh2x4AaABAg
# Confidence: high
# Subtype: pro_european_ancorare
# Noroc de uniunea europeana ce ne mai civilizam si noi ca altfel am fi fost saracii europei
# ================================================================================
# ID: yt_Fcmw2yFzz8I_UgwMe5IGw4bDWJFHOrN4AaABAg
# Confidence: high
# Subtype: pro_european_ancorare
# În primul rând, când vine vorba de taxe, uită-te la ce accize se plătesc la combustibil. Deci, da, unu care merge cu mașina plătește mai multe taxe decât un pieton. Însă, în București e o nenorocire făcută de toți șoferii. Chiar dacă îl costă 10 lei el nu plătește ci pune mașina ca un rahat. Prima manevră este mărirea taxelor la modul cel mai mic 200 de euro și de la 2000 de euro dacă are mai mult de 10 ani. Să pună taxa de oraș pentru cine vine din afara lui. Amenzi și ridicat de mașini. Așa se face în Europa….daca tot veni vorba. Sunt sofer înrăit dar sunt dispus sa plătesc banii ăștia. Ii am, când n-oi avea, merg cu autobuzul….
# ================================================================================
# ID: yt_Fcmw2yFzz8I_UgyPxrTBuHLiG7Dr6hJ4AaABAg
# Confidence: high
# Subtype: pro_european_ancorare
# desi suntem in ue, cu resurse si exemple, suntem in continuare o natie ignoranta si slab educata, dar peste inca 10-20 ani, cine stie
# ================================================================================
# ID: yt_Gk7qe_F1KWE_UgxPusjJdRH1UNTSI8V4AaABAg
# Confidence: high
# Subtype: aparare_institutionala_procedurala
# Sunt de a acord ca "votul util" e o tampenie nedemocratica dar pragul ala electoral eu zic ca e bun de 5% cum au majoritatea tarilor. Daca las sa intre toti si am 20 de partide cum ai zis tu risti sa ai instabilitate politica si nu o sa se formeze nici o majoritate pentru a guverna.
# ================================================================================
# ID: yt_xaM1SfOOgZs_UgxFqYmg1nbnyxxE9wx4AaABAg
# Confidence: high
# Subtype: pro_european_ancorare
# Romania are un parteriat strategic cu Statele Unite, pe care ori il respecta ori il denunta! Nu poti umbla cu fundul in doua luntrii!
# ================================================================================
# ID: yt_tl5fs9uHD8A_Ugwjh8sgt35fzGqTyF14AaABAg
# Confidence: high
# Subtype: pro_european_ancorare
# FELICITARI MIRUTA DIN SPANIA UNDE TRAIESC DE 30 DE ANI : ANALIZA TA ESTE BINE DOCUMENTATA SI REALISTA ! SPRE DEOSEBIRE DE POSTDECEMBRISTII CARE LATRA LOZINCI COMUNISTE EXPIRATE TU SPUI LUCRURILOR PE NUME ! VAD CA USA SI ISRAEL STIU FOARTE BINE CE AU DE FACUT ! INCA O CHESTIUNE IMPORTANTA - TOT CE FACI RAU SE PLATESTE - IRANUL ESTE DEPASITA TEHNOLOGIC SI MILITAR ! RESTUL ESTE ISTORIE !!
# ================================================================================
# ID: yt_E5bgKFYt_W8_UgwiKl6bINjnfg7jBI54AaABAg
# Confidence: high
# Subtype: aparare_institutionala_procedurala
# Nu mai dati hate,votați cu cine vreti fara sa jigniti,nu sunteti obligati sa votati pnl.
# ================================================================================
# ID: yt_qo87_bdwUb0_Ugxq8zUX_YkAkLqTC3V4AaABAg
# Confidence: high
# Subtype: pro_european_ancorare
# Lasati orgoliile deoparte, fragmentati electoratul pro-european.... Nu doar voi, ci toti cei de dreapta...
# ================================================================================
# ID: yt_ccMTOZvat7U_UgzhDG55pAwghRJzLh14AaABAg
# Confidence: high
# Subtype: pro_european_ancorare
# de apreciat tot ce ati realizat pana acum in Oradea sunteti demn de toata lauda felicitari !!!Oradea un oras european !!!
# ================================================================================
# ID: yt_qo87_bdwUb0_UgwMTVjRNz9kNGI0Led4AaABAg
# Confidence: high
# Subtype: pro_european_ancorare
# Hai ca se poate sa avem un Bucuresti demn de o capitala europeană! Ana la primarie! 💚💚💚
# ================================================================================
# ID: yt_LaJHhVE344g_Ugz3d33EzOBgE9onrJ94AaABAg
# Confidence: high
# Subtype: aparare_institutionala_procedurala
# Pai cum sa mai candideze? Nu e deja la al 2-lea mandat? Apoi, are varsta pe care o avea Biden de radea (si) el. Daca in Consitutia SUA exista o limita minima pt candidatii la presedintie (35 ani) nu e normal si de bun simt sa fie si o limita maxima?!? Ca altfel uite cu ce te alegi 🎃 daca n-ai din ce alege... (ca la noi, din pacate!)
# ================================================================================
# ID: yt_whXg_RKoyoU_Ugxa6w6U31S5U0xhKZZ4AaABAg
# Confidence: high
# Subtype: pro_european_ancorare
# MULTĂ LUME ȘI MAI ALES AMERICANI--CRED CĂ PESTE 60% DINTRE AMERICANI--CONSIDERĂ CĂ TRUMP ARE ȘI PROBLEME DE SĂNĂTATE MENTALĂ, AMERICANII---UN POPOR CARE ARE DEMOCRAȚIA ÎN SÂNGE ÎL VOR ELIMINA ÎNTR-UN FEL ÎNAINTE DE A FACE MULT RĂU ,AMRICANILOR DAR ȘI ÎNTREGII OMENIRI!!!!
# ================================================================================
# ID: yt_CGguFSFzJv8_UgyZlddCC20nQtYVsjd4AaABAg
# Confidence: high
# Subtype: aparare_institutionala_procedurala
# Traditia asta americana democratica o admirati dvs, d-le Tanase, cu toată stima, dar sunteti mult prea idealist vizavi de America si demoncratia ei, presedintii etc. Admir si eu diverse lucruri, chiar persoane din SUA, dar punctual, nicidecum la pachet cu toata America. Legat de parcuri, spatii verzi distruse ale Bukarachiului, trebuie implementate legi care vor criminaliza orice defrisare, toaletare a oricarui copac, chiar aflat in curtea particulara a unora; sa fie amendati toti criminalii de mediu, cu sume de la 3000€/copac in sus, cu achitarea amenzii in 2-4 saptamani, sau executare silita!
# ================================================================================
# ID: yt__8uDDh_S4zk_UgxhizYCZ6-r-NO4xat4AaABAg
# Confidence: high
# Subtype: aparare_institutionala_procedurala
# 1:01:06 Care e problema?Orice cetățean,cu orice fel de studii are dreptul sa candideze la președinție dacă vrea.Conditia e sa adune numărul de semnături.
# ================================================================================
# ID: yt_Dvw1tNAc_kU_UgwhTlAk7cIQ-vQNEdp4AaABAg
# Confidence: high
# Subtype: pro_european_ancorare
# VICTORIE Ucraina Forte Zelenschi forte UE Euronato 🇺🇦💯🇺🇦🇺🇦🇪🇺🇺🇦🇺🇦🇺🇦🇪🇺🇺🇦🇺🇦🇺🇦🇪🇺
# ================================================================================
# ID: yt_HDsCdSOtxO0_UgyEEhPD6pwEkPv-htp4AaABAg
# Confidence: high
# Subtype: aparare_institutionala_procedurala
# Sa se adune Fizic cei 900 magistrati care au semnat acea scrisoare de sustinere, si sa se dezbata acest subiect impreuna cu toti cei implicati, in Live Stream. Asa nu o mai poate ocoli nimeni.
# ================================================================================
# ID: yt_Vpfd5aXku18_UgyQEJvt2BIGaJcgppB4AaABAg
# Confidence: high
# Subtype: pro_european_ancorare
# Aderarea la UE nu va distruge Moldova. O va ridica la fel cum a ridicat Romania. Salariul in Romania era 110 euro acum e la 750 de euro aproape . Mergeti spre UE ca o sa ajungeti la bunastare .
# ================================================================================
# ID: yt_joXkZDqGZQU_Ugz-Gq_EtUxaaZD_8Y94AaABAg
# Confidence: high
# Subtype: aparare_institutionala_procedurala
# trebuie sustinut Zelensky , este un presedinte care isi apara propia tara de o invazie straina !! ca acei straini sunt rusi ,extraterestri nici nu mai conteaza ce sunt ,,,,,,trebuie respectate legile internationale .
# ================================================================================
# ID: yt_N5paaKW5FKc_UgyT9W1iuYdLeQOiEsF4AaABAg
# Confidence: high
# Subtype: aparare_institutionala_procedurala
# Oribile experiente. Le mulțumim femeilor ca au povestit. Sa speram ca autoritatile vor lua masuri si individul va plati si chiar disparea de pe scena publică si din profesie. Le multumim si jurnalistilor pentru efortul lor.
# ================================================================================
# ID: yt_N5paaKW5FKc_UgxpnYNsu7bwO-opJ9J4AaABAg
# Confidence: high
# Subtype: aparare_institutionala_procedurala
# Obsedat sexual, a vizionat filme ptr adulti unde ne este aratat ca poti cu usurinta sa agati o femeie cu usurinta...omul este posedat de duhul Sex'ului. Vreti nu vreti, lumea duhurilor este reala si care nu crede, sa citeasca Biblia. Este un abuzator si trebuie inchis!
# ================================================================================
# ID: yt_N5paaKW5FKc_UgxIXnoGQiwcHb3EFPl4AaABAg
# Confidence: high
# Subtype: aparare_institutionala_procedurala
# Scârbos, hilar...greu de ascultat! Legea să-și spună cuvântul și să fie pedepsit după faptele săvârșite.
# ================================================================================
# ID: yt_N5paaKW5FKc_UgzyQfviujsxAMEjkrR4AaABAg
# Confidence: high
# Subtype: aparare_institutionala_procedurala
# Sper ca instituțiile statului să-i interzică să mai apară in mass-media și pe orice platformă online. Păcat de aceste femei care au trecut prin acele momente cu acest individ psihopat.
# ================================================================================
# ID: yt_HxlQbrgEUU8_UgxDoeJWrWYqKUQASzd4AaABAg
# Confidence: high
# Subtype: aparare_institutionala_procedurala
# OMS e o organizație care ar trebui destructurata si supusa unui scrutin legal pentru genocid. Dar pentru vidanjorii din latrine e becul din weceul din fundul curtii😂
# ================================================================================
# ID: yt_N5paaKW5FKc_Ugxore1lgim0YGCI33p4AaABAg
# Confidence: high
# Subtype: aparare_institutionala_procedurala
# Mult curaj şi forță acestor doamne ,domnişoare că au denunțat ! ❤ Acest escroc trebuie judecat şi pedepsit !
# ================================================================================
# ID: yt_N5paaKW5FKc_UgxSP7up4ADhtt6L2E94AaABAg
# Confidence: high
# Subtype: aparare_institutionala_procedurala
# De fapt omul e psihopat nu psiholog.Trebuie să-și primească pedeapsa.
# ================================================================================
# ID: yt_N5paaKW5FKc_UgzAzXl3UvV_nVQu0Xx4AaABAg
# Confidence: high
# Subtype: aparare_institutionala_procedurala
# A primit drept de practica de la Colegiul medicilor in 2008. A absovit in 1988, colegiul medicilor a fost reglementat abia in 2006, pana atunci diploma de licenta era suficienta pentru a practica medicina. As fi preferat un material fara judecata de valoare si interpretare din partea reporteritei, doar fapte si declaratii. Sper ca justitia sa fie oarba si sa se aplice corect!
# ================================================================================
# ID: yt_8XaNWSfaLxE_UgwXGD9CNPZB7vipxuB4AaABAg
# Confidence: high
# Subtype: pro_european_ancorare
# Asta ar trebui să ne pună pe gânduri și pe noi, ce încredere să mai avem noi în sprijinul american. Trebui să privim realitatea așa cum este și să strângem rândurile cu aliați noștri europeni.
# ================================================================================
# ID: yt_8XaNWSfaLxE_Ugxbp7vvhgtpWgcgyBx4AaABAg
# Confidence: high
# Subtype: pro_european_ancorare
# Dacă SUA nu măi trimite arme în Europa, maxim 2luni suntem terminați și noi și slavă Ucraina 😂😂😂😂😂
# ================================================================================
# ID: yt_a2NSq8TduHw_Ugwg-iCjmC9gjYu5qPF4AaABAg
# Confidence: high
# Subtype: aparare_institutionala_procedurala
# Putin este un criminal care trebuie sa raspunda pt crimele care le.a comandat.
# ================================================================================
# ID: yt_a2NSq8TduHw_UgySSkGWwdvcCZFqZeh4AaABAg
# Confidence: high
# Subtype: aparare_institutionala_procedurala
# Pensiile în România sunt cele mai mici din UE, iar inflația în România este cea mai mare din UE! Trebuie respectată legea pensiilor și acordate indexările la pensii cu rata inflației!
# ================================================================================
# ID: yt_stxoPQZOAMU_UgzZ2jPcSRiXqryN2-Z4AaABAg
# Confidence: high
# Subtype: aparare_institutionala_procedurala
# Votul este independent si democratic votez cu cine merita ok.
# ================================================================================
# ID: yt_yEuctxNb4O0_UgwVpDXf89umBJlMdid4AaABAg
# Confidence: high
# Subtype: aparare_institutionala_procedurala
# Domnule președinte, de ce ce nu ați luat problemele din justiție să le discutați în CSM, în cadrul legal pe care vi-l oferă Constituția ?
# ================================================================================
# ID: yt_IDHDLcsiSZA_UgzdIm-wVhoZb663esR4AaABAg
# Confidence: high
# Subtype: pro_european_ancorare
# Mulțumim, Recorder! Să ne unim în Statele Unite ale Europei, cu o armată și monedă unică. Nu trebuie să ne mai căciulim la americani, nu mai sunt de încredere.
# ================================================================================
# ID: yt_XOejd9J2xqc_Ugzq6_KCKMBC4mxzPdh4AaABAg
# Confidence: high
# Subtype: pro_european_ancorare
# PERSPECTIVA MEA E CLA 2:22 RA, E OPTIMA! VOTEZ NICUSOR DAN!VREAU SA RAMANEM PE CALEA DEMOCRATIEI EUROPENE, NU RUSESTI, NU UNGURESTI!
# ================================================================================
# ID: yt_XOejd9J2xqc_UgyW8KjWhCfAE20twSd4AaABAg
# Confidence: high
# Subtype: aparare_institutionala_procedurala
# PERSPECTIVA MEA E CLARA, E OPTIMA. VOTEZ NICUSOR DAN! RAMANEM PE CALEA DEMOCRATIEI! APARAM VIITORUL COPIILOR NOSTRI!
# ================================================================================
# ID: yt_N5paaKW5FKc_Ugyh9o49alrmVw5i67F4AaABAg
# Confidence: high
# Subtype: aparare_institutionala_procedurala
# La fel că în milioane de mesaje pe feizbuc a feministelor ,care vor decăderea bărbaților ,printre care multe psiholoage ,divorțate ,care , dau lecții despre familii ,cînd habar nu au ,ce este familia și natura femeii , acum ,acest domn este tot bărbat și fiind și un terapeut , foarte invidiat ,toți nepricepuții și frustratele ,femei care urăsc bărbatu , îl atacă Numai un judecător ,specializat ,care vede ,că a dispărut iubirea și empatia femeii ,poate opri acest ,atac ,nefondat
# ================================================================================
# ID: yt_eFMaDoWc2Wg_UgzphJYZtAvroIgoyFd4AaABAg
# Confidence: high
# Subtype: pro_european_ancorare
# Daca Bucureștiul este o problema stați cât de departe puteți de Paris.... Sau Roma.... Sau orice capitala europeana unde sunt mai mulți imigranți decât molecule de apa. Bucureștiul nu e perfect dar este mult mai safe decât orice capitala din vest
# ================================================================================
# ID: yt_N5paaKW5FKc_Ugyr7nRINmg68VWwPjx4AaABAg
# Confidence: high
# Subtype: aparare_institutionala_procedurala
# Abuzurile sexuale sint parte din procesele care se judeca la tribunal . Vinovăția Doctorului Andrei nu este încă clară , urmează verdictul . Legea prevede 10 ani de închisoare , iar victimele primesc o suma se bani . Tot ce speculam înainte de a avea rezultatul procesului este o pierdere inutila de Timp . Jurnalistul este un om minunat, însă nu este omul care reprezintă legea , nici avocat si nici judecător . Adevarul se afla pe masa judecătorilor si nu pe YouTube ,

# %%
# elimin textele slabe și păstrez 50

REMOVE_IDS = [
    # pune aici ID-urile textelor slabe
]

clean_df = (
    my_df[~my_df["id"].isin(REMOVE_IDS)]
    .head(50)
    .copy()
)

clean_df["agent"] = MY_AGENT
clean_df["slug"] = meta["slug"]
clean_df["personality"] = meta["personality"]
clean_df["speaks"] = meta["speaks"]
clean_df["definition"] = meta["definition"]

print("Texte finale:", len(clean_df))
clean_df[["id", "agent", "text"]].head()
# Out:
# Texte finale: 50
#                                             id         agent  \
# 420  yt_FAe_Sqr2vfU_UgzfkQjlhFS0o3ZaCMl4AaABAg  Pro-european
# 547  yt_XlCX1l_6feU_UgwBIpp5ZbEtJkybe3t4AaABAg  Pro-european
# 527  yt_Fcmw2yFzz8I_UgxuNvJZTDz3pFm5Ijh4AaABAg  Pro-european
# 558  yt_Gk7qe_F1KWE_Ugw6Diry83RDiew6P4V4AaABAg  Pro-european
# 559  yt_Pk7Qkhnt4Bs_UgwxY19uJCh0c9RP4U54AaABAg  Pro-european
#
#                                                   text
# 420  Mă bucur să văd un Președinte care se comportă...
# 547  meritocratie in politica inseamna, totusi, alt...
# 527  Deci exemplu asta cu Parisul cred ca e cea mai...
# 558  Ce sunt cu torți trolli ăștia din comentarii? ...
# 559  Sanatate si putere de munca domnule presedinte...

# %% [markdown]
# ### Descrierea agentului tău
# Înainte să exporți bula curată, descrie în 5–7 rânduri ce fel de voce discursivă are agentul ales.
# Nu descrie o persoană reală. Descrie un tip de discurs observat în corpus.
# Răspunde la aceste întrebări:
# - Cum vede acest agent instituțiile, politica sau actorii publici?
# - Ce ton folosește cel mai des?
# - Ce tip de argumente sau acuzații apar frecvent?
# - Ce îl diferențiază de celelalte bule?
# - Ce ar trebui să păstreze un viitor agent AI ca să sune coerent cu această bulă?

# %% [markdown]
# descriere:
# -
# -
# -

# %%
# export bula curată pentru etapa următoare

OUT_DIR = Path("data/bubbles")
OUT_DIR.mkdir(parents=True, exist_ok=True)

out_path = OUT_DIR / f"{meta['slug']}.jsonl"

clean_df.to_json(out_path, orient="records", lines=True, force_ascii=False)

print("Salvat:", out_path)
# Out:
# Salvat: data\bubbles\pro_european.jsonl
